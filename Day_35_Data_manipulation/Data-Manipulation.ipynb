# %%
import pandas as pd

titanic_df = pd.read_csv("Titanic_data.csv")

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Inserting and Deleting Column

# %%
# Dropping a column
# dataframe.drop(<column_name>, axis)
# axis : {0 or 'index', 1 or 'columns'}, default 0
# Whether to drop lables from the index (0 or 'index') or columns (1 or 'columns')
# inplace = True  : inplace change data

titanic_df.drop("PassengerId", axis = 1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titanic_df.drop("PassengerId", axis = 1, inplace = False)
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.drop("PassengerId", axis = 1, inplace = True)
titanic_df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
titanic_df.drop([0,2,5], axis = 0, inplace = True)
titanic_df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 1  female  38.0      1      0  PC 17599  71.2833   C85        C
# 3  female  35.0      1      0    113803  53.1000  C123        S
# 4    male  35.0      0      0    373450   8.0500   NaN        S
# 6    male  54.0      0      0     17463  51.8625   E46        S
# 7    male   2.0      3      1    349909  21.0750   NaN        S

# %%
titanic_df['Name'][1].split(",")[0]
# Out:
# 'Cumings'

# %%
last_name = [name.split(",")[0] for name in titanic_df["Name"]]
last_name
# Out:
# ['Cumings',
#  'Futrelle',
#  'Allen',
#  'McCarthy',
#  'Palsson',
#  'Johnson',
#  'Nasser',
#  'Sandstrom',
#  'Bonnell',
#  'Saundercock',
#  'Andersson',
#  'Vestrom',
#  'Hewlett',
#  'Rice',
#  'Williams',
#  'Vander Planke',
#  'Masselmani',
#  'Fynney',
#  'Beesley',
#  'McGowan',
#  'Sloper',
#  'Palsson',
#  'Asplund',
#  'Emir',
#  'Fortune',
#  "O'Dwyer",
#  'Todoroff',
#  'Uruchurtu',
#  'Spencer',
#  'Glynn',
#  'Wheadon',
#  'Meyer',
#  'Holverson',
#  'Mamee',
#  'Cann',
#  'Vander Planke',
#  'Nicola-Yarred',
#  'Ahlin',
#  'Turpin',
#  'Kraeff',
#  'Laroche',
#  'Devaney',
#  'Rogers',
#  'Lennon',
#  "O'Driscoll",
#  'Samaan',
#  'Arnold-Franchi',
#  'Panula',
#  'Nosworthy',
#  'Harper',
#  'Faunthorpe',
#  'Ostby',
#  'Woolner',
#  'Rugg',
#  'Novel',
#  'West',
#  'Goodwin',
#  'Sirayanian',
#  'Icard',
#  'Harris',
#  'Skoog',
#  'Stewart',
#  'Moubarek',
#  'Nye',
#  'Crease',
#  'Andersson',
#  'Kink',
#  'Jenkin',
#  'Goodwin',
#  'Hood',
# ...

# %%
len(last_name)
# Out:
# 888

# %%
titanic_df['Last_Name'] = last_name

# %%
titanic_df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked Last_Name
# 1  female  38.0      1      0  PC 17599  71.2833   C85        C   Cumings
# 3  female  35.0      1      0    113803  53.1000  C123        S  Futrelle
# 4    male  35.0      0      0    373450   8.0500   NaN        S     Allen
# 6    male  54.0      0      0     17463  51.8625   E46        S  McCarthy
# 7    male   2.0      3      1    349909  21.0750   NaN        S   Palsson

# %%
titanic_df['Name'][1].split(".")[0].split(",")[1]
# Out:
# ' Mrs'

# %%
titanic_df.drop(['Last_Name'], axis = 1, inplace = True)

# %%
titanic_df
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# 6           0       1                            McCarthy, Mr. Timothy J
# 7           0       3                     Palsson, Master. Gosta Leonard
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ### Handling NaN or Null Value

# %%
titanic_df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         176
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       684
# Embarked      2
# dtype: int64

# %% [markdown]
# 1. Remove Null Values
# 2. Imputation
# 3. Feature Engineering

# %%
# Removing Null Columns
titanic_df[titanic_df['Embarked'].isna()]
# Out:
#      Survived  Pclass                                       Name     Sex  \
# 61          1       1                        Icard, Miss. Amelie  female
# 829         1       1  Stone, Mrs. George Nelson (Martha Evelyn)  female
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   38.0      0      0  113572  80.0   B28      NaN
# 829  62.0      0      0  113572  80.0   B28      NaN

# %%
titanic_df_filter = titanic_df[titanic_df['Embarked'].notna()]

# > dropna
titanic_df.dropna(axis = 0, how = 'any', subset= "Embarked", ignore_index= True)
# Out:
#      Survived  Pclass                                               Name  \
# 0           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 1           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 2           0       3                           Allen, Mr. William Henry
# 3           0       1                            McCarthy, Mr. Timothy J
# 4           0       3                     Palsson, Master. Gosta Leonard
# ..        ...     ...                                                ...
# 881         0       2                              Montvila, Rev. Juozas
# 882         1       1                       Graham, Miss. Margaret Edith
# 883         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 884         1       1                              Behr, Mr. Karl Howell
# 885         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %%
titanic_df_filter.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         176
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       684
# Embarked      0
# dtype: int64

# %%
#Imputation (Age) ## fill(Age) value
print(titanic_df_filter.Age.mean())
titanic_df_filter.Age.plot.hist(bins = 20, grid =  True)
# Out:
# 29.657985915492954
# <Axes: ylabel='Frequency'>

# %%
mean_age = titanic_df['Age'].mean()
mean_age
# Out:
# np.float64(29.71512640449438)

# %%
titanic_df_filter['Age'].fillna(value = mean_age, inplace= True)
# Out:
# /var/folders/dh/hwqk2ngs1nl5cyy_vk8pdc1m0000gn/T/ipykernel_18028/2303432609.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic_df_filter['Age'].fillna(value = mean_age, inplace= True)

# %%
titanic_df_filter.Age.plot.hist(bins = 20, grid =  True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Assigment: Imputation of Age Column w.r.t gender provided.
titanic_df_filter['Age'][titanic_df_filter['Sex'] == 'female'].fillna
# Out:
# <bound method NDFrame.fillna of 1      38.000000
# 3      35.000000
# 8      27.000000
# 9      14.000000
# 10      4.000000
#          ...
# 880    25.000000
# 882    22.000000
# 885    39.000000
# 887    19.000000
# 888    29.715126
# Name: Age, Length: 311, dtype: float64>

# %%
titanic_df['Cabin']
# Out:
# 1       C85
# 3      C123
# 4       NaN
# 6       E46
# 7       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 888, dtype: object

# %%
# Feature from Null Value
titanic_df_filter['Cabin'] = titanic_df_filter['Cabin'].notna().astype(int)
titanic_df_filter.loc[:,'Cabin'] = titanic_df_filter['Cabin'].notna().astype(int)
# Out:
# /var/folders/dh/hwqk2ngs1nl5cyy_vk8pdc1m0000gn/T/ipykernel_18028/2563388462.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic_df_filter['Cabin'] = titanic_df_filter['Cabin'].notna().astype(int)

# %%
titanic_df_filter.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
titanic_df_filter.head()
# Out:
#    Survived  Pclass                                               Name  \
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
#
#       Sex   Age  SibSp  Parch    Ticket     Fare  Cabin Embarked
# 1  female  38.0      1      0  PC 17599  71.2833      1        C
# 3  female  35.0      1      0    113803  53.1000      1        S
# 4    male  35.0      0      0    373450   8.0500      1        S
# 6    male  54.0      0      0     17463  51.8625      1        S
# 7    male   2.0      3      1    349909  21.0750      1        S

# %% [markdown]
# ### Handling Outliers

# %%
titanic_df_filter.Age.plot.box()
# Out:
# <Axes: >

# %%
Q1 = titanic_df_filter.Age.quantile(q= 0.25)
Q3 = titanic_df_filter.Age.quantile(q= 0.75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR
lower_limit = Q1 - 1.5 * IQR

print(upper_limit, ",", lower_limit)
# Out:
# 54.5 , 2.5

# %%
titanic_df_filter[(titanic_df_filter.Age > upper_limit) | (titanic_df_filter.Age < lower_limit)]
# Out:
#      Survived  Pclass                                           Name     Sex  \
# 7           0       3                 Palsson, Master. Gosta Leonard    male
# 11          1       1                       Bonnell, Miss. Elizabeth  female
# 15          1       2               Hewlett, Mrs. (Mary D Kingcome)   female
# 16          0       3                           Rice, Master. Eugene    male
# 33          0       2                          Wheadon, Mr. Edward H    male
# ..        ...     ...                                            ...     ...
# 824         0       3                   Panula, Master. Urho Abraham    male
# 827         1       2                          Mallet, Master. Andre    male
# 831         1       2                Richards, Master. George Sibley    male
# 851         0       3                            Svensson, Mr. Johan    male
# 879         1       1  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female
#
# ...

# %% [markdown]
# ### Handling Null Value For Age

# %%
#1. Initials
#2. Each Group of initlas mean
#3. Impute to respective group

# %%
def get_initials(fullname):
    firstname = fullname.split(",")[-1]
    inititals = firstname.split(".")[0]
    return inititals.strip()
#        OR

# get_initials = lambda x: x.split(",")[-1].split(".")[0].strip()

# %%
# dataframe.apply()

titanic_df['Initials'] = titanic_df['Name'].apply(get_initials)

# %%
titanic_df['Initials'].value_counts()
# Out:
# Initials
# Mr              515
# Miss            181
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Mlle              2
# Major             2
# Col               2
# the Countess      1
# Capt              1
# Ms                1
# Sir               1
# Lady              1
# Mme               1
# Don               1
# Jonkheer          1
# Name: count, dtype: int64

# %%
# dataframe.replace()
replace_dict = {
    "Dr" : "Mr",
    "Col" : "Mr",
    "Mlle" : "Miss",
    "Ms" : "Mrs",
    "Mme" : "Mrs",
    "Don" : "Mr",
    "Lady" : "Miss",
    "Sir" : "Mr",
    "Capt" : "Mr",
    "Jonkheer" : "Master",
    "the Countess" : "Mrs",
    "Major" : "Mr"
    
}
titanic_df['Initials'].replace(to_replace= replace_dict, inplace = True)

# %%
group_by_initials = titanic_df.groupby(by= "Initials")
group_by_initials.Age.mean()
# Out:
# Initials
# Master     5.477568
# Miss      21.952703
# Mr        32.889024
# Mrs       35.693694
# Rev       43.166667
# Name: Age, dtype: float64

# %%
# Dataframe.transorm()

series_of_mean = group_by_initials["Age"].transform("mean")

# %%
titanic_df.Age.fillna(series_of_mean, inplace=True)

# %%
titanic_df.Age.plot.hist(bins= 20)
# Out:
# <Axes: ylabel='Frequency'>
